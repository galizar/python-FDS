# %%
# !pip install PyDrive
# !git clone https://github.com/LeCrunchic/colablib
  
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from colablib.utilities import *
# Out:
# Collecting PyDrive
#   Downloading https://files.pythonhosted.org/packages/52/e0/0e64788e5dd58ce2d6934549676243dc69d982f198524be9b99e9c2a4fd5/PyDrive-1.3.1.tar.gz (987kB)
#     100% |████████████████████████████████| 993kB 9.9MB/s
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.6.7)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.0)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.11.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.11.3)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.4)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.2)
# Building wheels for collected packages: PyDrive
# done
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built PyDrive
# Installing collected packages: PyDrive
# Successfully installed PyDrive-1.3.1
# Cloning into 'colablib'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 26 (delta 7), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (26/26), done.

# %%
get_file('1mDKpY8m4tpsEUHvNSbQtmDsUwvHd40c6', 'resilience.csv')

# %%
resil = pd.read_csv('resilience.csv')

# %%
resil.head()
# Out:
#     IDR  Female              Group  QoL  MS.QoL  WHOQOL.PH  WHOQOL.PSY  \
# 0  IDR1       1          Clerkship    7       7      39.29       50.00
# 1  IDR2       0  Clinical Sciences    7       5      67.86       54.17
# 2  IDR3       1  Clinical Sciences    9       7      60.71       45.83
# 3  IDR4       0  Clinical Sciences    8       9      92.86       70.83
# 4  IDR5       0  Clinical Sciences   10      10      89.29       91.67
#
#    WHOQOL.SOC  WHOQOL.ENV  DREEM.L      ...       DREEM.At  DREEM.S.SP  \
# 0       33.33       46.88       24      ...             26           9
# 1       16.67       65.63       23      ...             20          10
# 2       41.67       68.75       24      ...             28          22
# 3       75.00       81.25       44      ...             34          22
# 4      100.00       87.50       35      ...             36          21
#
#    DREEM.GS  Resilience  BDI  Age  School legal status  School location  \
# 0       107          78   13   26               Public     Other cities
# 1        98          73   23   22               Public     Other cities
# 2       118          85   10   22               Public    State capital
# 3       165          86    3   23              Private     Other cities
# 4       152          93    0   21              Private     Other cities
#
#   State Anxiety Trait anxiety
# 0            42            48
# 1            51            60
# 2            59            58
# 3            42            25
# 4            31            22
#
# [5 rows x 22 columns]

# %%
sum(resil.iloc[:10,:]['MS.QoL'] > 5)
# Out:
# 7
